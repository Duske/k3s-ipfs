# %%
import numpy
from scipy.optimize import curve_fit
from matplotlib.ticker import MaxNLocator
import matplotlib.pyplot as plt
import pandas as pd
size=15
params = {'legend.fontsize': 'large',
          'figure.figsize': (9,6),
          'axes.labelsize': size,
          'axes.titlesize': size,
          'xtick.labelsize': size*0.75,
          'ytick.labelsize': size*0.75,
          'axes.titlepad': 25}
plt.rcParams.update(params)

df1 = pd.read_csv("Cluster-100mb-10-series.csv", sep=';')
df1_mean= df1.mean().to_numpy()/1000
df1_max= df1.max().to_numpy()/1000
df1_min= df1.min().to_numpy()/1000

sizes = [1,5,10,15,20,25]
fig = plt.figure()
ax = fig.gca()
print(df1_mean)
plt.plot(sizes, df1_mean, 'o-', color='#1A3A82', label="Durchschnitt")
plt.fill_between(x=sizes,y1=df1_min,y2=df1_max, color='#C9ECFF', label='Max/Min')
plt.xlabel('Clustergröße')
plt.ylabel('Zeit [s]')
plt.axhline(y=5, color="#1A3A82", linestyle='dashed', linewidth=1, label="HTTP", xmin=0.04, xmax=0.96) # 5
plt.xticks(sizes)
plt.yticks(numpy.arange(0,55,10))
plt.legend(title="", loc='upper left')
#plt.title("Laden einer Datei: 100MB")
fig.savefig('cluster-ipfs-100mb.pdf')
# Out:
# [ 30.33170315  19.56137359  22.29515022  21.33462892  31.41259836
#   35.93346342]

# %%
import numpy

from scipy.optimize import curve_fit
from matplotlib.ticker import MaxNLocator
import matplotlib.pyplot as plt
import pandas as pd
size=15
params = {'legend.fontsize': 'large',
          'figure.figsize': (9,6),
          'axes.labelsize': size,
          'axes.titlesize': size,
          'xtick.labelsize': size*0.75,
          'ytick.labelsize': size*0.75,
          'axes.titlepad': 25}
plt.rcParams.update(params)

df1 = pd.read_csv("Cluster-10mb-50-series.csv", sep=';')
df1_mean= df1.mean().to_numpy()/1000
df1_max= df1.max().to_numpy()/1000
df1_min= df1.min().to_numpy()/1000

sizes = [1,5,10,15,20,25]
fig = plt.figure()
ax = fig.gca()
plt.plot(sizes, df1_mean, 'o-', color='#1A3A82', label="Durchschnitt")
plt.fill_between(x=sizes,y1=df1_min,y2=df1_max, color='#C9ECFF', label='Max/Min')
plt.axhline(y=0.6, color="#1A3A82", linestyle='dashed', linewidth=1, label="HTTP", xmin=0.04, xmax=0.96) # 5
plt.yticks(numpy.arange(0,3.5,0.5))
plt.xlabel('Clustergröße')
plt.ylabel('Zeit [s]')
plt.xticks(sizes)
plt.legend(title="", loc='upper right')
#plt.title("Laden einer Datei: 10MB")
fig.savefig('cluster-ipfs-10mb.pdf')

# %%
import numpy
from scipy.optimize import curve_fit
from matplotlib.ticker import MaxNLocator
import matplotlib.pyplot as plt
import pandas as pd
size=15
params = {'legend.fontsize': 'large',
          'figure.figsize': (9,6),
          'axes.labelsize': size,
          'axes.titlesize': size,
          'xtick.labelsize': size*0.75,
          'ytick.labelsize': size*0.75,
          'axes.titlepad': 25}
plt.rcParams.update(params)

df1 = pd.read_csv("Cluster-1mb-50-series.csv", sep=';')
df1_mean= df1.mean().to_numpy()/1000
df1_max= df1.max().to_numpy()/1000
df1_min= df1.min().to_numpy()/1000

sizes = [1,5,10,15,20,25]
fig = plt.figure()
ax = fig.gca()
plt.plot(sizes, df1_mean, 'o-', color='#1A3A82', label="Durchschnitt")
plt.fill_between(x=sizes,y1=df1_min,y2=df1_max, color='#C9ECFF', label='Max/Min')
plt.axhline(y=0.12, color="#1A3A82", linestyle='dashed', linewidth=1, label="HTTP", xmin=0.04, xmax=0.96) # 5
plt.yticks(numpy.arange(0,0.7,0.1))
plt.xlabel('Clustergröße')
plt.ylabel('Zeit [s]')
plt.xticks(sizes)
plt.legend(title="", loc='upper right')
#plt.title("Laden einer Datei: 1MB")
fig.savefig('cluster-ipfs-1mb.pdf')
