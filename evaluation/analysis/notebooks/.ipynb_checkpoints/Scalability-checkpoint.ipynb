# %%
x <- c(1,2,3,4)
y <- c(157,
       81,
       52,
       45)
ymax <- max(y)
ymin <- min(y)
x2 <-x^2
quad <- seq(1, 4, 0.1)
quad2 <- quad^2



fit <- lm(y ~ x + x2)
plot(x, y, type = "p", col="blue", xlim = c(1, 4), ylim = c(min(ymin),max(ymax)),
     main = "Processing 60 workflows on 1 to 4 Raspberry Pis", xlab = "Raspberry Pi Cluster Size", ylab = "Overall processing time [m]"
    )
predictedcounts <- predict(fit,list(x=quad, x2=quad2))
lines(quad, predictedcounts, col = "red",
lwd = 1)
legend("topright", legend=c("quadratic estimate y = 261 - 122,750x +17,250x^2", "Data"),
       col=c("red", "blue"), lty = 1, cex=0.8)
summary(fit)
# Out:
# Call:
# lm(formula = y ~ x + x2)
#
# Residuals:
#     1     2     3     4
#  1.25 -3.75  3.75 -1.25
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  261.250     15.562  16.787   0.0379 *
# x           -122.750     14.197  -8.646   0.0733 .
# x2            17.250      2.795   6.172   0.1023
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 5.59 on 1 degrees of freedom
# Multiple R-squared:  0.996,	Adjusted R-squared:  0.9881
# F-statistic: 125.6 on 2 and 1 DF,  p-value: 0.06296
# Plot with title “Processing 60 workflows on 1 to 4 Raspberry Pis”
