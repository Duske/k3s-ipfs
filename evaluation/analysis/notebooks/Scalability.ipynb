# %%
x <- c(1,2,3,4,5)
y <- c(157,
       81,
       52,
       45,
      34)
ymax <- max(y)
ymin <- min(y)
x2 <-x^2
quad <- seq(1, 5, 0.1)
quad2 <- quad^2



fit <- lm(y ~ 60/x*)
plot(x, y, type = "p", col="blue", xlim = c(1, 5), ylim = c(min(ymin),max(ymax)),
     main = "Processing 60 workflows on 1 to 4 Raspberry Pis", xlab = "Raspberry Pi Cluster Size", ylab = "Overall processing time [m]"
    )
#predictedcounts <- predict(fit,list(x=quad, x2=quad2))
predictedcounts <- predict(fit,list(x=quad))
lines(quad, predictedcounts, col = "red",
lwd = 1)
legend("topright", legend=c("quadratic estimate y = 261 - 122,750x +17,250x^2", "Data"),
       col=c("red", "blue"), lty = 1, cex=0.8)
summary(fit)
# Out:
# Call:
# lm(formula = y ~ log(x))
#
# Residuals:
#       1       2       3       4       5
#  10.334 -12.917 -11.061   3.832   9.813
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   146.67      11.39  12.878  0.00101 **
# log(x)        -76.10      10.23  -7.441  0.00502 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 13 on 3 degrees of freedom
# Multiple R-squared:  0.9486,	Adjusted R-squared:  0.9315
# F-statistic: 55.36 on 1 and 3 DF,  p-value: 0.005025
# Plot with title “Processing 60 workflows on 1 to 4 Raspberry Pis”
